# %%
# Out:
# Componente 1:
# 2473-Wood rough,painted,prsvd. Prop: 29.217%
# 7753-Dishwashing machines of the household type. Prop: 0.234%
# 7591-Parts and accessories of the photocopying and thermocopying apparatus of. Prop: 0.234%
# 2462-Sawdust and wood waste and scrap, whether or not agglomerated in logs, br. Prop: 0.234%
# 8966-Antiques of an age exceeding one hundred years. Prop: 0.234%
# 7425-Rotary positive displacement pumps, n.e.s.. Prop: 0.234%
# 7841-Chassis fitted with engines, for the motor vehicles of groups 722, 781, 7. Prop: 0.234%
# 6957-Tools of two or more of the headings of subgroups 695.2 through 695.5, pu. Prop: 0.234%
# 6968-Knives with cutting blades, serrated or not (including pruning knives), o. Prop: 0.234%
# 2223-Cotton seeds. Prop: 0.234%
# 7529-Data processing equipment, n.e.s.. Prop: 0.234%
# 2232-Palm nuts and kernels. Prop: 0.234%
# 7832-Road tractors for semi-trailers. Prop: 0.234%
# ...
